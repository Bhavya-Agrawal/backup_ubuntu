# %%
from sklearn.datasets import load_iris
from sklearn import tree
import graphviz
#from sklearn.cross_validation import train_test_split

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
#test_size indicates the size of data we want to give for training the machine 
iris = load_iris()
train_data,test_data,train_target,test_target=train_test_split(iris.data,iris.target,test_size=0.8)

# %%
#known or expected output

print(test_target)
# Out:
# [2 1 2 1 2 1 2 0 2 1 2 1 0 2 2 0 2 0 0 2 0 0 0 0 2 1 1 0 2 0 1 0 1 1 1 0 0
#  0 0 1 2 0 2 0 2 0 1 0 2 2 1 2 2 0 0 1 2 0 1 2 2 1 1 2 2 2 1 1 2 1 2 2 1 1
#  2 1 1 0 0 1 0 0 0 2 1 2 1 1 2 0 2 2 1 0 1 1 0 0 1 2 1 0 2 1 2 1 0 1 0 2 2
#  1 1 2 0 0 0 2 0 0]

# %%
clf = tree.DecisionTreeClassifier()
# input is in train_data and output is as per train_target
trained = clf.fit(train_data,train_target)

# %%
#we need to predict output as per test_data so give it in predict function
predicted = trained.predict(test_data)

# %%
#predicted output
print(predicted)
# Out:
# [2 1 2 1 2 1 2 0 1 1 1 1 0 2 2 0 2 0 0 2 0 0 0 0 2 1 1 0 2 0 1 0 1 1 1 0 0
#  0 0 1 2 0 2 0 2 0 1 0 2 2 1 2 2 0 0 1 2 0 1 2 2 1 2 2 2 2 1 1 1 1 2 1 1 1
#  2 1 1 0 0 1 0 0 0 2 1 2 1 1 2 0 2 2 1 0 1 1 0 0 1 2 1 0 2 1 1 1 0 1 0 2 2
#  1 1 2 0 0 0 2 0 0]

# %%
# print percentage of accuracy
pct = accuracy_score(test_target,predicted)

# %%
print(pct)
# Out:
# 0.95

# %%
tree.export_graphviz(clf)
out_data = tree.export_graphviz(clf,out_file=None,feature_names=iris.feature_names,class_names=iris.target_names)
graphviz.Source(out_data)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/tree/export.py:399: DeprecationWarning: out_file can be set to None starting from 0.18. This will be the default in 0.20.
#   DeprecationWarning)
